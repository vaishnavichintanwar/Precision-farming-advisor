# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt5

import seaborn as sns

# %%
df1 = pd.read_csv('/home/user/Downloads/Fertilizer_Prediction.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df1 = pd.read_csv('/home/user/Downloads/Fertilizer_Prediction.csv')
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
# ...

# %%
df1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df1.shape
#
# NameError: name 'df1' is not defined

# %%
df1.head(5)
# Out:
#    Temperature  Humidity  Rainfall    pH    N    P    K        Soil     Crop  \
# 0        24.87     82.84    295.61  6.59  4.0  2.0  2.5      Clayey     rice
# 1        28.69     96.65    178.96  6.08  4.0  4.0  4.0    laterite  Coconut
# 2        20.27     81.64    270.44  5.01  4.0  4.0  2.0  silty clay     rice
# 3        25.07     95.02    192.90  5.55  2.0  2.1  3.5       sandy  Coconut
# 4        25.04     95.90    174.80  6.18  2.0  3.9  2.1     coastal  Coconut
#
#      Fertilizer
# 0   DAP and MOP
# 1      Good NPK
# 2           MOP
# 3  Urea and DAP
# 4  Urea and MOP

# %%
df2 = pd.read_csv('/home/user/Documents/fertilizer_notebook/Fertilizer2.csv')

# %%
df2.shape
# Out:
# (99, 9)

# %%
df2.head(5)
# Out:
#    Temparature  Humidity   Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0           26         52        38     Sandy      Maize        37          0
# 1           29         52        45     Loamy  Sugarcane        12          0
# 2           34         65        62     Black     Cotton         7          9
# 3           32         62        34       Red    Tobacco        22          0
# 4           28         54        46    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
df.shape
# Out:
# (299, 19)

# %%
df.head(5)
# Out:
#    Temperature  Humidity  Rainfall    pH    N    P    K        Soil     Crop  \
# 0        24.87     82.84    295.61  6.59  4.0  2.0  2.5      Clayey     rice
# 1        28.69     96.65    178.96  6.08  4.0  4.0  4.0    laterite  Coconut
# 2        20.27     81.64    270.44  5.01  4.0  4.0  2.0  silty clay     rice
# 3        25.07     95.02    192.90  5.55  2.0  2.1  3.5       sandy  Coconut
# 4        25.04     95.90    174.80  6.18  2.0  3.9  2.1     coastal  Coconut
#
#      Fertilizer  Temparature  Humidity   Moisture Soil Type Crop Type  \
# 0   DAP and MOP          NaN        NaN       NaN       NaN       NaN
# 1      Good NPK          NaN        NaN       NaN       NaN       NaN
# 2           MOP          NaN        NaN       NaN       NaN       NaN
# 3  Urea and DAP          NaN        NaN       NaN       NaN       NaN
# 4  Urea and MOP          NaN        NaN       NaN       NaN       NaN
#
#    Nitrogen  Potassium  Phosphorous Fertilizer Name
# ...
