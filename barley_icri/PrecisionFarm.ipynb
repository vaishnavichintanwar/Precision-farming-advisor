# %%
import pandas as pd

# %%
df = pd.read_json("/home/user/Documents/finalProject/Project-icrisat/icrisat-crops.json")
df
# Out:
#     dist_code  year  state    state_name dist_name  rice_area  rice_prod  \
# 0           1  1966     14  Chhattisgarh      Durg     548.00     185.00
# 1           1  1967     14  Chhattisgarh      Durg     547.00     409.00
# 2           1  1968     14  Chhattisgarh      Durg     556.30     468.00
# 3           1  1969     14  Chhattisgarh      Durg     563.40     400.80
# 4           1  1970     14  Chhattisgarh      Durg     571.60     473.60
# ..        ...   ...    ...           ...       ...        ...        ...
# 95          2  2009     14  Chhattisgarh    Bastar     626.66     682.46
# 96          2  2010     14  Chhattisgarh    Bastar     621.89    1184.98
# 97          2  2011     14  Chhattisgarh    Bastar     627.73     772.88
# 98          2  2012     14  Chhattisgarh    Bastar     637.80    1341.33
# 99          2  2013     14  Chhattisgarh    Bastar     642.79    1265.91
#
#     rice_yield  wheat_area  wheat_prod  ...  soyabean_yield  oilseeds_area  \
# ...

# %%
df.columns
# Out:
# Index(['dist_code', 'year', 'state', 'state_name', 'dist_name', 'rice_area',
#        'rice_prod', 'rice_yield', 'wheat_area', 'wheat_prod', 'wheat_yield',
#        'kharif_sorghum_area', 'kharif_sorghum_prod', 'kharif_sorghum_yield',
#        'rabi_sorghum_area', 'rabi_sorghum_prod', 'rabi_sorghum_yield',
#        'sorghum_area', 'sorghum_prod', 'sorghum_yield', 'pearl_millet_area',
#        'pearl_millet_prod', 'pearl_millet_yield', 'maize_area', 'maize_prod',
#        'maize_yield', 'finger_millet_area', 'finger_millet_prod',
#        'finger_millet_yield', 'barley_area', 'barley_prod', 'barley_yield',
#        'chickpea_area', 'chickpea_prod', 'chickpea_yield', 'pigeonpea_area',
#        'pigeonpea_prod', 'pigeonpea_yield', 'minor_pulses_area',
#        'minor_pulses_prod', 'minor_pulses_yield', 'groundnut_area',
#        'groundnut_prod', 'groundnut_yield', 'sesamum_area', 'sesamum_prod',
#        'sesamum_yield', 'rapeseed_area', 'rapeseed_prod', 'rapeseed_yield',
# ...

# %%
df = pd.read_json("/home/user/Documents/finalProject/Project-icrisat/icrisat-101-200.json")
df
# Out:
#     dist_code  year  state    state_name dist_name  rice_area  rice_prod  \
# 0           1  1966     14  Chhattisgarh      Durg     548.00     185.00
# 1           1  1967     14  Chhattisgarh      Durg     547.00     409.00
# 2           1  1968     14  Chhattisgarh      Durg     556.30     468.00
# 3           1  1969     14  Chhattisgarh      Durg     563.40     400.80
# 4           1  1970     14  Chhattisgarh      Durg     571.60     473.60
# ..        ...   ...    ...           ...       ...        ...        ...
# 95          2  2009     14  Chhattisgarh    Bastar     626.66     682.46
# 96          2  2010     14  Chhattisgarh    Bastar     621.89    1184.98
# 97          2  2011     14  Chhattisgarh    Bastar     627.73     772.88
# 98          2  2012     14  Chhattisgarh    Bastar     637.80    1341.33
# 99          2  2013     14  Chhattisgarh    Bastar     642.79    1265.91
#
#     rice_yield  wheat_area  wheat_prod  ...  soyabean_yield  oilseeds_area  \
# ...

# %%
df = pd.read_json('/home/user/Documents/finalProject/Project-icrisat/icrisat-201-300.json')
df
# Out:
#     dist_code  year  state    state_name dist_name  rice_area  rice_prod  \
# 0           4  2010     14  Chhattisgarh  Bilaspur     705.67    1333.61
# 1           4  2011     14  Chhattisgarh  Bilaspur     749.08    1557.35
# 2           4  2012     14  Chhattisgarh  Bilaspur     747.27    1746.82
# 3           4  2013     14  Chhattisgarh  Bilaspur     726.15    1577.16
# 4           4  2014     14  Chhattisgarh  Bilaspur     728.84    1683.92
# ..        ...   ...    ...           ...       ...        ...        ...
# 95          6  2001     14  Chhattisgarh   Surguja     384.88     513.26
# 96          6  2002     14  Chhattisgarh   Surguja     377.85     257.13
# 97          6  2003     14  Chhattisgarh   Surguja     383.94     503.40
# 98          6  2004     14  Chhattisgarh   Surguja     380.93     374.25
# 99          6  2005     14  Chhattisgarh   Surguja     380.93     374.25
#
#     rice_yield  wheat_area  wheat_prod  ...  soyabean_yield  oilseeds_area  \
# ...

# %%
df = pd.read_json()
df

# %%
df = pd.read_json()
df

# %%
df = pd.read_json("/home/user/Downloads/Project-icrisat/icrisat_801-900.json")
df
# Out:
#     dist_code  year  state      state_name   dist_name  rice_area  rice_prod  \
# 0          16  1986      6  Madhya Pradesh  Chhatarpur       22.0       10.0
# 1          16  1987      6  Madhya Pradesh  Chhatarpur       20.0       15.0
# 2          16  1988      6  Madhya Pradesh  Chhatarpur       22.3       16.4
# 3          16  1989      6  Madhya Pradesh  Chhatarpur       19.0       13.6
# 4          16  1990      6  Madhya Pradesh  Chhatarpur       20.0       18.7
# ..        ...   ...    ...             ...         ...        ...        ...
# 95         18  1977      6  Madhya Pradesh        Rewa      119.2       79.1
# 96         18  1978      6  Madhya Pradesh        Rewa      119.9       57.4
# 97         18  1979      6  Madhya Pradesh        Rewa      115.0        3.4
# 98         18  1980      6  Madhya Pradesh        Rewa      117.8       60.0
# 99         18  1981      6  Madhya Pradesh        Rewa      121.7       66.3
#
# ...

# %%
df = pd.read_json("/home/user/Downloads/Project-icrisat/icrisat_901-1000.json")

# %%
df
# Out:
#     dist_code  year  state      state_name   dist_name  rice_area  rice_prod  \
# 0          16  1986      6  Madhya Pradesh  Chhatarpur       22.0       10.0
# 1          16  1987      6  Madhya Pradesh  Chhatarpur       20.0       15.0
# 2          16  1988      6  Madhya Pradesh  Chhatarpur       22.3       16.4
# 3          16  1989      6  Madhya Pradesh  Chhatarpur       19.0       13.6
# 4          16  1990      6  Madhya Pradesh  Chhatarpur       20.0       18.7
# ..        ...   ...    ...             ...         ...        ...        ...
# 95         18  1977      6  Madhya Pradesh        Rewa      119.2       79.1
# 96         18  1978      6  Madhya Pradesh        Rewa      119.9       57.4
# 97         18  1979      6  Madhya Pradesh        Rewa      115.0        3.4
# 98         18  1980      6  Madhya Pradesh        Rewa      117.8       60.0
# 99         18  1981      6  Madhya Pradesh        Rewa      121.7       66.3
#
# ...
