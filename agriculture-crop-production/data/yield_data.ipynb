# %%
import pandas as pd

# %% [markdown]
# ### Load the dataset

# %%
df1 = pd.read_csv('production_crops_e_asia.csv')

# %%
df1.head(2)
# Out:
#    area_code         area  item_code                 item  element_code  \
# 0          2  Afghanistan        221  Almonds, with shell          5312
# 1          2  Afghanistan        221  Almonds, with shell          5419
#
#           element   unit  y1961 y1961f  y1962  ...    y2015  y2015f    y2016  \
# 0  Area harvested     ha    NaN    NaN    NaN  ...  14676.0     NaN  19481.0
# 1           Yield  hg/ha    NaN    NaN    NaN  ...  16521.0      Fc  16859.0
#
#    y2016f    y2017  y2017f    y2018  y2018f    y2019  y2019f
# 0     NaN  19793.0     NaN  20053.0     NaN  29203.0     NaN
# 1      Fc  13788.0      Fc  17161.0      Fc  13083.0      Fc
#
# [2 rows x 125 columns]

# %%
df1.columns
# Out:
# Index(['area_code', 'area', 'item_code', 'item', 'element_code', 'element',
#        'unit', 'y1961', 'y1961f', 'y1962',
#        ...
#        'y2015', 'y2015f', 'y2016', 'y2016f', 'y2017', 'y2017f', 'y2018',
#        'y2018f', 'y2019', 'y2019f'],
#       dtype='object', length=125)

# %%
df1.shape
# Out:
# (9638, 125)

# %%
#df1.isnull().sum()

# %%
df2 = pd.read_csv('production_crops_e_africa.csv')

# %%
df3 = pd.read_csv('production_crops_e_americas.csv')

# %%
df4 = pd.read_csv('production_crops_e_europe.csv')

# %%
df5 = pd.read_csv('production_crops_e_oceania.csv')

# %%
data = pd.concat([df1, df2, df3,df4,df5], ignore_index=True)

# %%
data.shape
# Out:
# (38146, 125)

# %%
# Display basic information about the dataset
#print(data.info())

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38146 entries, 0 to 38145
# Columns: 125 entries, area_code to y2019f
# dtypes: float64(59), int64(3), object(63)
# memory usage: 36.4+ MB

# %%
# Check summary statistics
#print(data.describe())

data.describe()
# Out:
#           area_code     item_code  element_code         y1961         y1962  \
# count  38146.000000  38146.000000  38146.000000  2.263900e+04  2.265800e+04
# mean     130.297069    614.361663   5414.258349  3.711481e+05  3.787092e+05
# std       75.053504    547.910943     82.044592  3.506653e+06  3.529416e+06
# min        1.000000     15.000000   5312.000000  0.000000e+00  0.000000e+00
# 25%       63.000000    236.000000   5312.000000  3.100000e+03  3.200000e+03
# 50%      126.000000    446.000000   5419.000000  1.541700e+04  1.597000e+04
# 75%      196.000000    656.000000   5510.000000  8.273350e+04  8.380300e+04
# max      299.000000   1841.000000   5510.000000  1.763400e+08  1.645933e+08
#
#               y1963         y1964         y1965         y1966         y1967  \
# count  2.265600e+04  2.268300e+04  2.268300e+04  2.278000e+04  2.281500e+04
# mean   3.833825e+05  3.976123e+05  4.004895e+05  4.117802e+05  4.202198e+05
# ...

# %%
# Display the first few rows of the dataset

data.head(5)
# Out:
#    area_code         area  item_code                              item  \
# 0          2  Afghanistan        221               Almonds, with shell
# 1          2  Afghanistan        221               Almonds, with shell
# 2          2  Afghanistan        221               Almonds, with shell
# 3          2  Afghanistan        711  Anise, badian, fennel, coriander
# 4          2  Afghanistan        711  Anise, badian, fennel, coriander
#
#    element_code         element    unit  y1961 y1961f  y1962  ...    y2015  \
# 0          5312  Area harvested      ha    NaN    NaN    NaN  ...  14676.0
# 1          5419           Yield   hg/ha    NaN    NaN    NaN  ...  16521.0
# 2          5510      Production  tonnes    NaN    NaN    NaN  ...  24246.0
# 3          5312  Area harvested      ha    NaN      M    NaN  ...  25000.0
# 4          5419           Yield   hg/ha    NaN    NaN    NaN  ...   7200.0
#
#    y2015f    y2016  y2016f    y2017  y2017f    y2018  y2018f    y2019  y2019f
# ...

# %%
data.columns
# Out:
# Index(['area_code', 'area', 'item_code', 'item', 'element_code', 'element',
#        'unit', 'y1961', 'y1961f', 'y1962',
#        ...
#        'y2015', 'y2015f', 'y2016', 'y2016f', 'y2017', 'y2017f', 'y2018',
#        'y2018f', 'y2019', 'y2019f'],
#       dtype='object', length=125)

# %%
# Check for data types
#print(data.dtypes)

data.dtypes
# Out:
# area_code         int64
# area             object
# item_code         int64
# item             object
# element_code      int64
#                  ...
# y2017f           object
# y2018           float64
# y2018f           object
# y2019           float64
# y2019f           object
# Length: 125, dtype: object

# %%
# Check for missing values
#print(data.isnull().sum())

data.isnull().sum()
# Out:
# area_code           0
# area                0
# item_code           0
# item                0
# element_code        0
#                 ...
# y2017f          14296
# y2018            4754
# y2018f          14975
# y2019            4709
# y2019f          13872
# Length: 125, dtype: int64

# %%
# Check for duplicates

print("\nDuplicate rows:")
duplicates = data[data.duplicated()]
print(duplicates)
# Out:
# Duplicate rows:
# Empty DataFrame
# Columns: [area_code, area, item_code, item, element_code, element, unit, y1961, y1961f, y1962, y1962f, y1963, y1963f, y1964, y1964f, y1965, y1965f, y1966, y1966f, y1967, y1967f, y1968, y1968f, y1969, y1969f, y1970, y1970f, y1971, y1971f, y1972, y1972f, y1973, y1973f, y1974, y1974f, y1975, y1975f, y1976, y1976f, y1977, y1977f, y1978, y1978f, y1979, y1979f, y1980, y1980f, y1981, y1981f, y1982, y1982f, y1983, y1983f, y1984, y1984f, y1985, y1985f, y1986, y1986f, y1987, y1987f, y1988, y1988f, y1989, y1989f, y1990, y1990f, y1991, y1991f, y1992, y1992f, y1993, y1993f, y1994, y1994f, y1995, y1995f, y1996, y1996f, y1997, y1997f, y1998, y1998f, y1999, y1999f, y2000, y2000f, y2001, y2001f, y2002, y2002f, y2003, y2003f, y2004, y2004f, y2005, y2005f, y2006, y2006f, y2007, ...]
# Index: []
#
# [0 rows x 125 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Display count plots for categorical columns
categorical_columns = data.select_dtypes(include='object').columns
for column in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=data, x=column)
    plt.title(f"Count Plot for {column}")
    plt.show()

# %%
# Drop rows with missing values
df = data.dropna()
df
# Out:
#        area_code         area  item_code                     item  \
# 7              2  Afghanistan        515                   Apples
# 10             2  Afghanistan        526                 Apricots
# 13             2  Afghanistan         44                   Barley
# 16             2  Afghanistan        558              Berries nes
# 17             2  Afghanistan        558              Berries nes
# ...          ...          ...        ...                      ...
# 38141        155      Vanuatu       1720  Roots and Tubers, Total
# 38142        155      Vanuatu       1720  Roots and Tubers, Total
# 38143        155      Vanuatu       1735       Vegetables Primary
# 38144        155      Vanuatu       1735       Vegetables Primary
# 38145        155      Vanuatu       1735       Vegetables Primary
#
#        element_code         element    unit     y1961 y1961f     y1962  ...  \
# 7              5419           Yield   hg/ha   68018.0     Fc   68018.0  ...
# ...

# %%
# check for the null values
df.isnull().values.any()
# Out:
# False

# %%
dummy = pd.get_dummies(df)
dummy
# Out:
#        area_code  item_code  element_code     y1961     y1962     y1963  \
# 7              2        515          5419   68018.0   68018.0   68018.0
# 10             2        526          5419   66390.0   66390.0   66390.0
# 13             2         44          5419   10800.0   10800.0   10800.0
# 16             2        558          5419   88235.0   88235.0   88235.0
# 17             2        558          5510   60000.0   60000.0   60000.0
# ...          ...        ...           ...       ...       ...       ...
# 38141        155       1720          5419  225455.0  227273.0  229091.0
# 38142        155       1720          5510   24800.0   25000.0   25200.0
# 38143        155       1735          5312     200.0     210.0     220.0
# 38144        155       1735          5419  150000.0  150000.0  150000.0
# 38145        155       1735          5510    3000.0    3150.0    3300.0
#
#           y1964     y1965     y1966     y1967  ...  y2018f_*  y2018f_A  \
# ...

# %%
# Display correlation matrix
#correlation_matrix = data.corr()
df.drop(['area_code', 'item_code', 'element_code'], axis=1)
#Y = df['Purchased']
# Out:
#               area                     item         element    unit     y1961  \
# 7      Afghanistan                   Apples           Yield   hg/ha   68018.0
# 10     Afghanistan                 Apricots           Yield   hg/ha   66390.0
# 13     Afghanistan                   Barley           Yield   hg/ha   10800.0
# 16     Afghanistan              Berries nes           Yield   hg/ha   88235.0
# 17     Afghanistan              Berries nes      Production  tonnes   60000.0
# ...            ...                      ...             ...     ...       ...
# 38141      Vanuatu  Roots and Tubers, Total           Yield   hg/ha  225455.0
# 38142      Vanuatu  Roots and Tubers, Total      Production  tonnes   24800.0
# 38143      Vanuatu       Vegetables Primary  Area harvested      ha     200.0
# 38144      Vanuatu       Vegetables Primary           Yield   hg/ha  150000.0
# 38145      Vanuatu       Vegetables Primary      Production  tonnes    3000.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10407 entries, 7 to 38145
# Columns: 125 entries, area_code to y2019f
# dtypes: float64(59), int64(3), object(63)
# memory usage: 10.0+ MB

# %%
df['area'].unique()
# Out:
# array(['Afghanistan', 'Bahrain', 'Bangladesh', 'Bhutan',
#        'Brunei Darussalam', 'Cambodia', 'China, Hong Kong SAR',
#        'China, Macao SAR', 'China, mainland', 'China, Taiwan Province of',
#        'Cyprus', "Democratic People's Republic of Korea", 'India',
#        'Indonesia', 'Iran (Islamic Republic of)', 'Iraq', 'Israel',
#        'Japan', 'Jordan', 'Kuwait', "Lao People's Democratic Republic",
#        'Lebanon', 'Malaysia', 'Maldives', 'Mongolia', 'Myanmar', 'Nepal',
#        'Oman', 'Pakistan', 'Philippines', 'Republic of Korea',
#        'Saudi Arabia', 'Singapore', 'Sri Lanka', 'Syrian Arab Republic',
#        'Thailand', 'Timor-Leste', 'Turkey', 'United Arab Emirates',
#        'Viet Nam', 'Yemen', 'Algeria', 'Angola', 'Benin', 'Botswana',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cameroon',
#        'Central African Republic', 'Chad', 'Comoros', 'Congo',
#        "Côte d'Ivoire", 'Democratic Republic of the Congo', 'Djibouti',
# ...

# %%
#df.nunique()
df['area'].nunique()
# Out:
# 166

# %%
df['item'].unique()
# Out:
# array(['Apples', 'Apricots', 'Barley', 'Berries nes', 'Figs',
#        'Fruit, citrus nes', 'Fruit, fresh nes', 'Fruit, stone nes',
#        'Grapes', 'Linseed', 'Maize', 'Melons, other (inc.cantaloupes)',
#        'Millet', 'Nuts nes', 'Olives', 'Oranges',
#        'Peaches and nectarines', 'Pears', 'Plums and sloes', 'Potatoes',
#        'Pulses nes', 'Rice, paddy',
#        'Rice, paddy (rice milled equivalent)', 'Seed cotton',
#        'Sesame seed', 'Sugar beet', 'Sugar cane', 'Sunflower seed',
#        'Vegetables, fresh nes', 'Watermelons', 'Wheat', 'Cereals, Total',
#        'Citrus Fruit, Total', 'Fibre Crops Primary', 'Fruit Primary',
#        'Oilcrops', 'Oilcrops, Cake Equivalent',
#        'Oilcrops, Oil Equivalent', 'Pulses, Total',
#        'Roots and Tubers, Total', 'Sugar Crops Primary',
#        'Treenuts, Total', 'Vegetables Primary', 'Bananas', 'Dates',
#        'Lemons and limes', 'Onions, dry', 'Tomatoes', 'Areca nuts',
# ...

# %%
df['item'].nunique()
# Out:
# 168

# %%
df['element'].unique()
# Out:
# array(['Yield', 'Production', 'Area harvested'], dtype=object)

# %%
df['element'].nunique()
# Out:
# 3

# %%
df['unit'].unique()
# Out:
# array(['hg/ha', 'tonnes', 'ha'], dtype=object)

# %%
df['unit'].fillna('Unknown', inplace=True)

# Standardizing or converting units to a common format
unit_mapping = {
    'ha': 'hectares',
    'hg/ha': 'hg per hectare',
    'tonnes': 'metric tonnes'
}

df['unit'] = df['unit'].map(unit_mapping)
# Out:
# /tmp/ipykernel_17795/1200552432.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['unit'].fillna('Unknown', inplace=True)
# /tmp/ipykernel_17795/1200552432.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['unit'] = df['unit'].map(unit_mapping)

# %%
df['unit'].unique()
# Out:
# array([nan], dtype=object)

# %%
df['unit'].nunique()
# Out:
# 3

# %%
df['y1961'].unique()
# Out:
# array([68018., 66390., 10800., ...,  2701., 18468., 29954.])

# %%
df['y1961'].nunique()
# Out:
# 6871

# %%
df['y1961f'].unique()
# Out:
# array(['Fc', '*', 'F', 'A'], dtype=object)

# %%
df['y1961f'].nunique()
# Out:
# 4

# %%
# Clean the 'y1961f' column
df['y1961f'] = df['y1961f'].str.replace(r'[^a-zA-Z]', '', regex=True)  # Remove non-alphabetic characters
df['y1961f'] = df['y1961f'].str.upper()  # Convert to uppercase (or use 'lower' for lowercase)

# Display the cleaned DataFrame
#df.head()
# Out:
# /tmp/ipykernel_17795/2501618422.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['y1961f'] = df['y1961f'].str.replace(r'[^a-zA-Z]', '', regex=True)  # Remove non-alphabetic characters
# /tmp/ipykernel_17795/2501618422.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['y1961f'] = df['y1961f'].str.upper()  # Convert to uppercase (or use 'lower' for lowercase)

# %%
df['y1961f'].unique()
# Out:
# array(['FC', '', 'F', 'A'], dtype=object)
